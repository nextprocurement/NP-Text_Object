# %%
import pathlib
import pandas as pd
import numpy as np
import re
import time
import fasttext
fasttext.FastText.eprint = lambda x: None
from huggingface_hub import hf_hub_download
from tqdm import tqdm

# %%
def get_lang(
    df: pd.DataFrame,
    col_calculate_on: str
) -> str:
    """Detects the language of a text column in a DataFrame using langdetect.

    Parameters
    ----------
    df : pd.DataFrame
        DataFrame containing the text column
    col_calculate_on : str
        Column name to calculate language on

    Returns
    -------
    df : pd.DataFrame
        DataFrame with the language column added to it as "lang"
    """

    def det(x: str) -> str:
        """
        Detects the language of a given text

        Parameters
        ----------
        x : str
            Text whose language is to be detected

        Returns
        -------
        lang : str
            Language of the text
        """

        try:
            lang = model.predict(x)[0][0].replace('__label__','')
        except Exception as e:
            print(e)
            lang = 'Other'
        return lang

    print(f"-- Detecting language...")
    start_time = time.time()

    df['lang'] = df[col_calculate_on].apply(det)

    print(f'-- -- Language detect finished in {(time.time() - start_time)}')

    return df

def normalize_string(s):
    # Convert to lower case
    #s = s.lower()
    # Remove punctuation and special characters
    #s = re.sub(r'[^\w\s]', '', s)
    # Remove extra spaces
    s = re.sub(r'\s+', ' ', s).strip()
    return s

# %%
path_texts = pathlib.Path("/export/data_ml4ds/NextProcurement/PLACE/BSC_procesados")
paths = []
paths = [path for path in path_texts.iterdir()]
print(*paths)
# Out:
# /export/data_ml4ds/NextProcurement/PLACE/BSC_procesados/procurements_file_15_containing_252064_docs_mark_fixed.parq /export/data_ml4ds/NextProcurement/PLACE/BSC_procesados/procurements_file_9_containing_250416_docs_mark_fixed.parq /export/data_ml4ds/NextProcurement/PLACE/BSC_procesados/procurements_file_6_containing_251105_docs_mark_fixed.parq /export/data_ml4ds/NextProcurement/PLACE/BSC_procesados/procurements_file_10_containing_251208_docs_mark_fixed.parq /export/data_ml4ds/NextProcurement/PLACE/BSC_procesados/procurements_file_8_containing_251687_docs_mark_fixed.parq /export/data_ml4ds/NextProcurement/PLACE/BSC_procesados/procurements_file_1_containing_251067_docs_mark_fixed.parq /export/data_ml4ds/NextProcurement/PLACE/BSC_procesados/procurements_file_11_containing_252661_docs_mark_fixed.parq /export/data_ml4ds/NextProcurement/PLACE/BSC_procesados/procurements_file_16_containing_92602_docs_mark_fixed.parq /export/data_ml4ds/NextProcurement/PLACE/BSC_procesados/procurements_file_3_containing_254088_docs_mark_fixed.parq /export/data_ml4ds/NextProcurement/PLACE/BSC_procesados/procurements_file_13_containing_250951_docs_mark_fixed.parq /export/data_ml4ds/NextProcurement/PLACE/BSC_procesados/procurements_file_4_containing_249935_docs_mark_fixed.parq /export/data_ml4ds/NextProcurement/PLACE/BSC_procesados/procurements_file_0_containing_252077_docs_mark_fixed.parq /export/data_ml4ds/NextProcurement/PLACE/BSC_procesados/procurements_file_12_containing_252483_docs_mark_fixed.parq /export/data_ml4ds/NextProcurement/PLACE/BSC_procesados/procurements_file_7_containing_250227_docs_mark_fixed.parq /export/data_ml4ds/NextProcurement/PLACE/BSC_procesados/procurements_file_2_containing_252000_docs_mark_fixed.parq /export/data_ml4ds/NextProcurement/PLACE/BSC_procesados/procurements_file_14_containing_250186_docs_mark_fixed.parq /export/data_ml4ds/NextProcurement/PLACE/BSC_procesados/procurements_file_5_containing_250098_docs_mark_fixed.parq

# %%
all_dfs = []
for path_ in tqdm(paths):
    df = pd.read_parquet(path_)
    all_dfs.append(df)
# Out:
# 100%|██████████| 17/17 [19:43<00:00, 69.63s/it]

# %%
combined_df = pd.concat(all_dfs)

# %%
model_path = hf_hub_download(repo_id="facebook/fasttext-language-identification", filename="model.bin")
model = fasttext.load_model(model_path)

# %%
combined_df["clean_extracted"] = combined_df["extracted"].apply(normalize_string)
combined_df["clean_extracted"] = combined_df["clean_extracted"].apply(lambda x: x[:1000])# keep first 1000 tokens to fasten language detection
combined_df = get_lang(combined_df, col_calculate_on = "clean_extracted")
combined_df
# Out:
# -- Detecting language...
# -- -- Language detect finished in 194.43360948562622
#        procurement_id                                        doc_name  \
# 2         ntp00114200  ntp00114200_Pliego_Prescripciones_tecnicas_URI
# 10        ntp00729859  ntp00729859_Pliego_Prescripciones_tecnicas_URI
# 23        ntp01335443  ntp01335443_Pliego_Prescripciones_tecnicas_URI
# 35        ntp00008052  ntp00008052_Pliego_Prescripciones_tecnicas_URI
# 40        ntp00196761  ntp00196761_Pliego_Prescripciones_tecnicas_URI
# ...               ...                                             ...
# 250028    ntp00582515  ntp00582515_Pliego_Prescripciones_tecnicas_URI
# 250038    ntp01351598  ntp01351598_Pliego_Prescripciones_tecnicas_URI
# 250067    ntp00566851  ntp00566851_Pliego_Prescripciones_tecnicas_URI
# 250078    ntp00882149  ntp00882149_Pliego_Prescripciones_tecnicas_URI
# 250091    ntp10549657  ntp10549657_Pliego_Prescripciones_tecnicas_URI
#
#                                                 extracted  \
# 2       g PLIEGO DE PRESCRI PCI ONES TÉCNI CAS\n S\n \...
# 10      PLIEGO DE PRESCRIPCIONES TÉCNICAS QUE HA DE RE...
# 23      PLIEGO DE PRESCRIPCIONES TÉCNICAS PARA LA CONT...
# 35      íHJJ Agencia de I'Habitatge\n FUU de Catalunya...
# 40      Ref: 50/088288.9/21\nAgencia de Vivienda Socia...
# ...                                                   ...
# 250028  sura\nPLIEGO DE PRESCRIPCIONES TÉCNICAS PARA L...
# 250038  2020/02293/01 14/07/2020\n \n ...\nCOLEGIO DE ...
# 250067  ANEX\nPliego de prescripciones técnicas que ha...
# 250078  a\n A\n S\nUNIVERSITAT\n POLITÉCNICA\n DE VALE...
# 250091  Ayuntamiento de Alhendín a\nZ\n 3532 L\n <\n O...
#
#                                            extracted_tags  \
# 2       [document, section, heading, section, heading,...
# 10      [document, section, heading, section, heading,...
# 23      [document, section, heading, body, p, p, p, p,...
# 35      [document, section, heading, section, heading,...
# 40      [document, section, body, p, section, heading,...
# ...                                                   ...
# 250028  [document, section, body, p, section, heading,...
# 250038  [document, section, body, p, section, heading,...
# 250067  [document, section, heading, body, p, p, p, p,...
# 250078  [document, section, body, p, section, heading,...
# 250091  [document, section, body, p, section, heading,...
#
#                                             texto_heading  \
# 2       [g PLIEGO DE PRESCRI PCI ONES TÉCNI CAS\n S\n ...
# 10      [PLIEGO DE PRESCRIPCIONES TÉCNICAS QUE HA DE R...
# 23      [PLIEGO DE PRESCRIPCIONES TÉCNICAS PARA LA CON...
# 35      [íHJJ Agencia de I'Habitatge\n FUU de Cataluny...
# 40      [Agencia de Vivienda Social\n CONSEJERÍA DE VI...
# ...                                                   ...
# 250028  [PLIEGO DE PRESCRIPCIONES TÉCNICAS PARA LA CON...
# 250038  [COLEGIO DE INGENIEROS DE CAMINOS,\n CANALES Y...
# 250067  [ANEX, Características técnicas de la aplicaci...
# 250078  [UNIVERSITAT\n POLITÉCNICA\n DE VALENCIA\n \n ...
# 250091  [Z\n 3532 L\n <\n O\n \n MEMORIA JUSTIFICATIVA...
#
#                                        embeddings_heading  \
# 2       [[-0.1855995, 0.10908591, 0.1287027, -0.085297...
# 10      [[-0.06488852, 0.03319587, 0.05720649, -0.2051...
# 23      [[0.11980498, -0.0047292123, 0.07927151, -0.05...
# 35      [[0.050423447, 0.10861048, 0.12632288, 0.06832...
# 40      [[0.2535557, 0.06023139, 0.13293944, 0.0011294...
# ...                                                   ...
# 250028  [[-0.101150624, 0.29571363, -0.01729959, 0.204...
# 250038  [[-0.041178588, -0.10482038, 0.20265633, 0.086...
# 250067  [[-0.02871781, 0.109616816, -0.03430078, 0.037...
# 250078  [[0.04755034, -0.071341686, 0.07659534, 0.1800...
# 250091  [[-0.028787123, 0.33844322, 0.021228943, 0.110...
#
#                                           clean_extracted      lang
# 2       g pliego de prescri pci ones técni cas s contr...  spa_Latn
# 10      pliego de prescripciones técnicas que ha de re...  spa_Latn
# 23      pliego de prescripciones técnicas para la cont...  spa_Latn
# 35      íhjj agencia de ihabitatge fuu de catalunya pl...  cat_Latn
# 40      ref 50088288921 agencia de vivienda social con...  spa_Latn
# ...                                                   ...       ...
# 250028  sura pliego de prescripciones técnicas para la...  ast_Latn
# 250038  20200229301 14072020 colegio de ingenieros de ...  spa_Latn
# 250067  anex pliego de prescripciones técnicas que ha ...  spa_Latn
# 250078  a a s universitat politécnica de valencia cont...  spa_Latn
# 250091  ayuntamiento de alhendín a z 3532 l o memoria ...  spa_Latn
#
# [455437 rows x 8 columns]

# %%
combined_df.lang.unique()
# Out:
# array(['spa_Latn', 'cat_Latn', 'glg_Latn', 'som_Latn', 'por_Latn',
#        'eus_Latn', 'oci_Latn', 'lmo_Latn', 'eng_Latn', 'wol_Latn',
#        'ast_Latn', 'est_Latn', 'vec_Latn', 'bug_Latn', 'fra_Latn',
#        'gaz_Latn', 'gom_Deva', 'slk_Latn', 'xho_Latn', 'ita_Latn',
#        'epo_Latn', 'lim_Latn', 'hun_Latn', 'kor_Hang', 'ron_Latn',
#        'ltz_Latn', 'fuv_Latn', 'vie_Latn', 'lus_Latn', 'yue_Hant',
#        'lvs_Latn', 'nld_Latn', 'ces_Latn', 'nav_Latn', 'fin_Latn',
#        'bos_Latn', 'gla_Latn', 'lit_Latn', 'quy_Latn', 'mos_Latn',
#        'hat_Latn', 'yor_Latn', 'nso_Latn', 'cym_Latn', 'lij_Latn',
#        'lug_Latn', 'aka_Latn', 'nno_Latn', 'scn_Latn', 'kab_Latn',
#        'pol_Latn', 'ind_Latn', 'afr_Latn'], dtype=object)

# %%
combined_df.columns
# Out:
# Index(['procurement_id', 'doc_name', 'extracted', 'extracted_tags',
#        'texto_heading', 'embeddings_heading', 'clean_extracted', 'lang'],
#       dtype='object')

# %%
df_cat = combined_df[combined_df.lang=="cat_Latn"].sample(n=75, random_state=1234_75)

# %%
df_cat["text"] = df_cat["extracted"].apply(normalize_string)
df_cat["objetivo"] = [""]*len(df_cat)
df_cat.to_parquet("cat.parquet")
df_cat[["procurement_id", "doc_name", "text", "objetivo"]].to_excel("tarea_gencat.xlsx")
df_cat[["procurement_id", "doc_name", "text", "objetivo"]]
# Out:
#        procurement_id                                        doc_name  \
# 80133     ntp01208301  ntp01208301_Pliego_Prescripciones_tecnicas_URI
# 151660    ntp00409894  ntp00409894_Pliego_Prescripciones_tecnicas_URI
# 92115     ntp00245710  ntp00245710_Pliego_Prescripciones_tecnicas_URI
# 65757     ntp00344652  ntp00344652_Pliego_Prescripciones_tecnicas_URI
# 120006    ntp00304919  ntp00304919_Pliego_Prescripciones_tecnicas_URI
# ...               ...                                             ...
# 242357    ntp01339344  ntp01339344_Pliego_Prescripciones_tecnicas_URI
# 156018    ntp00298986  ntp00298986_Pliego_Prescripciones_tecnicas_URI
# 212516    ntp00008945  ntp00008945_Pliego_Prescripciones_tecnicas_URI
# 157670    ntp00389749  ntp00389749_Pliego_Prescripciones_tecnicas_URI
# 191240    ntp00291430  ntp00291430_Pliego_Prescripciones_tecnicas_URI
#
#                                                      text objetivo
# 80133   Ajuntament de Manacor Exp. 524/2023 PLEC DE PR...
# 151660  Àrea de Serveis Generals Departament de Compra...
# 92115   I_ < > O C a < Exp. 905349/21 PLEC DE CONDICIO...
# 65757   Àrea de Presidència Subdirecció d'Imatge Corpo...
# 120006  Generalitat de Catalunya Departament de la Vic...
# ...                                                   ...      ...
# 242357  Ajuntament É} de Palma PLEC DE PRESCRIPCIONS T...
# 156018  Servei Catala de la Salut SCS-2022-389 Submini...
# 212516  E PLC_ppt_legionel-losi_20180306 AJUNTAMENT DE...
# 157670  PRESCRIPCIONS TECNIQUES QUE REGIRAN A LA CONTR...
# 191240  MILLORES A LES COBERTES DE L”ESCOLA D”EDUCACIÓ...
#
# [75 rows x 4 columns]

# %%
df_spa = combined_df[combined_df.lang=="spa_Latn"].sample(n=150, random_state=1234_75)

# %%
df_spa["text"] = df_spa["extracted"].apply(normalize_string)
df_spa["objetivo"] = [""]*len(df_spa)
df_spa.to_parquet("spa.parquet")
df_spa[["procurement_id", "doc_name", "text", "objetivo"]].to_excel("tarea_zaragoza_madrid.xlsx")
df_spa[["procurement_id", "doc_name", "text", "objetivo"]]
# Out:
#        procurement_id                                        doc_name  \
# 128403    ntp00617381  ntp00617381_Pliego_Prescripciones_tecnicas_URI
# 152306    ntp00552454  ntp00552454_Pliego_Prescripciones_tecnicas_URI
# 214074    ntp01175355  ntp01175355_Pliego_Prescripciones_tecnicas_URI
# 156951    ntp00348490  ntp00348490_Pliego_Prescripciones_tecnicas_URI
# 108923    ntp00573106  ntp00573106_Pliego_Prescripciones_tecnicas_URI
# ...               ...                                             ...
# 112135    ntp00506461  ntp00506461_Pliego_Prescripciones_tecnicas_URI
# 77689     ntp11215851  ntp11215851_Pliego_Prescripciones_tecnicas_URI
# 243516    ntp10327031  ntp10327031_Pliego_Prescripciones_tecnicas_URI
# 55806     ntp00438518  ntp00438518_Pliego_Prescripciones_tecnicas_URI
# 201888    ntp01338839  ntp01338839_Pliego_Prescripciones_tecnicas_URI
#
#                                                      text objetivo
# 128403  PLIEGO DE PRESCRIPCIONES TÉCNICAS PARTICULARES...
# 152306  de ERO EN — DE ARAGON E :' = EE Instiuto Arago...
# 214074  1ena Aeropuerto de Tenerife Norte- Ciudad de L...
# 156951  SEGURTASUN SAILA - DEPARTAMENTO DE SEGURIDAD A...
# 108923  PLIEGO DE PRESCRIPCIONES TÉCNICAS PARA LA CONT...
# ...                                                   ...      ...
# 112135  AYUNTAMIENTO DE __ Unión Europea Fondo Europeo...
# 77689   s PROVINCIA EXCMO CONCELLO = % DE DE E LUGO PA...
# 243516  $ Te MINISTERIO - Á |"€5J g Y SEGURIDAD SOCIAL...
# 55806   O P EXPEDIENTE N* INV 2018/04 . Universidad de...
# 201888  SUMINISTRO E INSTALACIÓN DE TECHOS METÁLICOS C...
#
# [150 rows x 4 columns]

# %%
df_spa.iloc[0:75][["procurement_id", "doc_name", "text", "objetivo"]].to_excel("tarea_zaragoza.xlsx")
df_spa.iloc[75:][["procurement_id", "doc_name", "text", "objetivo"]].to_excel("tarea_madrid.xlsx")
